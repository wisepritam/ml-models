# %% [markdown]
# # Train YOLO26n
#
# Nano variant — speed baseline. `BATCH=8`, `IMGSZ=1280`, `EPOCHS=150` (early stop @ epoch 92, patience=30).
# Outputs: `checkpoints/yolo26n/` · `results/metrics/yolo26n_metrics.csv` · `results/plots/yolo26n/`
#
# | Split | mAP@50 | mAP@50-95 | Precision | Recall |
# |---|---|---|---|---|
# | Val  | 0.6181 | 0.3885 | 0.6252 | 0.5903 |
# | Test | 0.5192 | 0.2884 | 0.4963 | 0.5700 |
#
# | Class | Val AP@50 | Test AP@50 |
# |---|---|---|
# | Trichomonas vaginalis      | 0.6090 | 0.4672 |
# | Bacterial vaginosis        | 0.7138 | 0.6771 |
# | Candida spp.               | 0.1948 | 0.3209 |
# | Actinomyces spp.           | 0.9550 | 0.6117 |

# %%
MODEL_VARIANT = 'yolo26n'
BATCH         = 8
EPOCHS        = 150
IMGSZ         = 1280
WORKERS       = 4
PATIENCE      = 30

from pathlib import Path
ROOT           = Path('../../../').resolve()
DATASET_YAML   = ROOT / 'models/organism_det/configs/dataset.yaml'
CHECKPOINT_DIR = ROOT / 'models/organism_det/checkpoints' / MODEL_VARIANT
METRICS_DIR    = ROOT / 'models/organism_det/results/metrics'
PLOTS_DIR      = ROOT / 'models/organism_det/results/plots' / MODEL_VARIANT

for d in [CHECKPOINT_DIR, METRICS_DIR, PLOTS_DIR]:
    d.mkdir(parents=True, exist_ok=True)

assert DATASET_YAML.exists(), f'Run 00_data_converter.ipynb first. Missing: {DATASET_YAML}'

# %%
import subprocess, sys

for pkg in ['ultralytics', 'pandas', 'matplotlib']:
    subprocess.check_call([sys.executable, '-m', 'pip', 'install', '-q', pkg])

import torch
import ultralytics
print(f'ultralytics {ultralytics.__version__}')
print(f'torch {torch.__version__}  |  CUDA: {torch.cuda.is_available()}')
if torch.cuda.is_available():
    props = torch.cuda.get_device_properties(0)
    print(f'GPU: {props.name}  |  VRAM: {props.total_memory / 1e9:.1f} GB')
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/home/pritamthapa/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ultralytics 8.4.60
# torch 2.12.0+cu130  |  CUDA: True
# GPU: NVIDIA GeForce RTX 4090  |  VRAM: 23.6 GB

# %%
from ultralytics import YOLO

model = YOLO(f'{MODEL_VARIANT}.pt')

model.train(
    data=str(DATASET_YAML),
    epochs=EPOCHS,
    imgsz=IMGSZ,
    batch=BATCH,
    workers=WORKERS,
    patience=PATIENCE,
    project=str(CHECKPOINT_DIR.parent),
    name=MODEL_VARIANT,
    exist_ok=True,
    optimizer='auto',
    mosaic=1.0,
    close_mosaic=10,
    copy_paste=0.3,
    flipud=0.5,
    fliplr=0.5,
    degrees=15.0,
    hsv_h=0.05,
    hsv_s=0.3,
    hsv_v=0.1,
    scale=0.5,
    plots=True,
    save=True,
    save_period=50,
    verbose=True,
)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.4.0/yolo26n.pt to 'yolo26n.pt': 100% ━━━━━━━━━━━━ 5.3MB 4.1MB/s 1.3s1.3s<0.0s.0s
# Ultralytics 8.4.60 🚀 Python-3.10.12 torch-2.12.0+cu130 CUDA:0 (NVIDIA GeForce RTX 4090, 22554MiB)
# engine/trainer: agnostic_nms=False, amp=True, angle=1.0, augment=False, auto_augment=randaugment, batch=8, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, cls_pw=0.0, compile=False, conf=None, copy_paste=0.3, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/home/pritamthapa/projects/cervical_cancer/ml-models/models/organism_det/configs/dataset.yaml, degrees=15.0, deterministic=True, device=None, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, end2end=None, epochs=150, erasing=0.4, exist_ok=True, fliplr=0.5, flipud=0.5, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.05, hsv_s=0.3, hsv_v=0.1, imgsz=1280, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolo26n.pt, momentum=0.937, mosaic=1.0, multi_scale=0.0, name=yolo26n, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=30, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/home/pritamthapa/projects/cervical_cancer/ml-models/models/organism_det/checkpoints, rect=False, resume=False, retina_masks=False, rle=1.0, save=True, save_conf=False, save_crop=False, save_dir=/home/pritamthapa/projects/cervical_cancer/ml-models/models/organism_det/checkpoints/yolo26n, save_frames=False, save_json=False, save_period=50, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=4, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/home/pritamthapa/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 4.6MB/s 0.2s 0.1s<0.2s
# Overriding model.yaml nc=80 with nc=4
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      6640  ultralytics.nn.modules.block.C3k2            [32, 64, 1, False, 0.25]
#   3                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#   4                  -1  1     26080  ultralytics.nn.modules.block.C3k2            [64, 128, 1, False, 0.25]
#   5                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#   6                  -1  1     87040  ultralytics.nn.modules.block.C3k2            [128, 128, 1, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    346112  ultralytics.nn.modules.block.C3k2            [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5, 3, True]
#  10                  -1  1    249728  ultralytics.nn.modules.block.C2PSA           [256, 256, 1]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  1    119808  ultralytics.nn.modules.block.C3k2            [384, 128, 1, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  1     34304  ultralytics.nn.modules.block.C3k2            [256, 64, 1, True]
#  17                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  1     95232  ultralytics.nn.modules.block.C3k2            [192, 128, 1, True]
#  20                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  1    463104  ultralytics.nn.modules.block.C3k2            [384, 256, 1, True, 0.5, True]
#  23        [16, 19, 22]  1    242736  ultralytics.nn.modules.head.Detect           [4, 1, True, [64, 128, 256]]
# YOLO26n summary: 260 layers, 2,505,360 parameters, 2,505,360 gradients, 5.8 GFLOPs
#
# Transferred 606/708 items from pretrained weights
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 365.3±73.6 MB/s, size: 133.2 KB)
# train: Scanning /home/pritamthapa/projects/cervical_cancer/ml-models/data/organisms_data/train/labels... 378 images, 12 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 378/378 5.1Kit/s 0.1s
# train: New cache created: /home/pritamthapa/projects/cervical_cancer/ml-models/data/organisms_data/train/labels.cache
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 301.8±68.3 MB/s, size: 108.0 KB)
# val: Scanning /home/pritamthapa/projects/cervical_cancer/ml-models/data/organisms_data/val/labels... 47 images, 5 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 47/47 3.5Kit/s 0.0s
# val: New cache created: /home/pritamthapa/projects/cervical_cancer/ml-models/data/organisms_data/val/labels.cache
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.00125, momentum=0.9) with parameter groups 114 weight(decay=0.0), 126 weight(decay=0.0005), 126 bias(decay=0.0)
# Plotting labels to /home/pritamthapa/projects/cervical_cancer/ml-models/models/organism_det/checkpoints/yolo26n/labels.jpg...
# Image sizes 1280 train, 1280 val
# Using 4 dataloader workers
# Logging results to /home/pritamthapa/projects/cervical_cancer/ml-models/models/organism_det/checkpoints/yolo26n
# Starting training for 150 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/150      5.55G      1.551      9.214    0.01075          2       1280: 100% ━━━━━━━━━━━━ 48/48 4.3it/s 11.1s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 2.1it/s 1.4s5.8s
#                    all         47        143    0.00239      0.306     0.0492     0.0278
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/150      5.55G      1.453       8.46   0.009886          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.9it/s 4.4s0.1s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 26.0it/s 0.1s
#                    all         47        143     0.0188      0.448       0.13     0.0789
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/150      5.55G      1.482      7.144    0.01038          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.9it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 26.9it/s 0.1s
#                    all         47        143      0.723      0.172      0.172     0.0646
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/150      5.56G      1.572      6.973    0.01141          2       1280: 100% ━━━━━━━━━━━━ 48/48 11.0it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 25.3it/s 0.1s
#                    all         47        143      0.691      0.222      0.219      0.108
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/150      5.56G      1.479      5.703     0.0102          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.9it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 25.4it/s 0.1s
#                    all         47        143       0.74       0.22      0.258      0.133
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/150      5.56G      1.507       5.23    0.01039          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.9it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 25.4it/s 0.1s
#                    all         47        143      0.779      0.255      0.269      0.147
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/150      5.56G      1.501      4.904    0.01021          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.9it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 25.8it/s 0.1s
#                    all         47        143       0.74      0.284      0.287       0.15
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/150      5.56G      1.437      4.362   0.009807          2       1280: 100% ━━━━━━━━━━━━ 48/48 11.0it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 26.3it/s 0.1s
#                    all         47        143      0.783      0.282      0.294      0.137
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/150      5.56G      1.438      3.864   0.009552          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.8it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 24.4it/s 0.1s
#                    all         47        143      0.788      0.258      0.291      0.138
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/150      5.56G      1.476      3.778    0.01004          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.9it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 25.6it/s 0.1s
#                    all         47        143      0.741      0.266      0.253      0.131
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/150      5.56G      1.456       3.45   0.009733          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.9it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 25.3it/s 0.1s
#                    all         47        143      0.812      0.246      0.294       0.15
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/150      5.56G      1.502      3.302    0.01049          2       1280: 100% ━━━━━━━━━━━━ 48/48 11.0it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 25.1it/s 0.1s
#                    all         47        143      0.735      0.336      0.428      0.186
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/150      5.56G      1.492      3.034    0.01011          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.9it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 24.8it/s 0.1s
#                    all         47        143      0.675      0.279      0.361      0.175
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/150      5.56G      1.491      2.875   0.009902          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.9it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 26.9it/s 0.1s
#                    all         47        143      0.772      0.279      0.374      0.204
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/150      5.56G      1.445      2.677   0.009529          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.9it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 25.6it/s 0.1s
#                    all         47        143      0.794      0.269      0.436      0.218
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/150      5.56G      1.467      2.669    0.01038          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.8it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 26.0it/s 0.1s
#                    all         47        143      0.691      0.382      0.476      0.281
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/150      5.56G      1.429      2.453   0.009961          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.9it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 25.4it/s 0.1s
#                    all         47        143      0.578      0.474      0.437      0.245
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/150      5.56G      1.462        2.4   0.009672          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.9it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 24.1it/s 0.1s
#                    all         47        143       0.64      0.367      0.416      0.224
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/150      5.56G      1.442      2.313    0.00968          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.8it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 25.1it/s 0.1s
#                    all         47        143      0.617       0.45       0.43      0.201
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/150      5.56G      1.419      2.353    0.01004          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.8it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 24.9it/s 0.1s
#                    all         47        143      0.732      0.404      0.469      0.259
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/150      5.56G      1.428      2.165   0.009231          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.8it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 25.3it/s 0.1s
#                    all         47        143      0.677      0.411      0.439      0.248
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/150      5.56G       1.43      2.137   0.009483          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.9it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 25.9it/s 0.1s
#                    all         47        143      0.607      0.472      0.435      0.209
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/150      5.56G      1.418      2.025   0.009645          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.9it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 26.2it/s 0.1s
#                    all         47        143      0.647      0.503      0.459      0.221
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/150      5.56G      1.435      1.995   0.009365          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.8it/s 4.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 25.6it/s 0.1s
#                    all         47        143      0.685       0.47      0.476      0.255
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/150      5.56G      1.441      1.992   0.009677          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.8it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 25.4it/s 0.1s
#                    all         47        143      0.709      0.384      0.499      0.272
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/150      5.56G      1.432      1.918   0.009186          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.9it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 25.7it/s 0.1s
#                    all         47        143       0.69      0.469      0.484      0.261
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/150      5.56G      1.379      1.883    0.01003          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.9it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 24.1it/s 0.1s
#                    all         47        143      0.663      0.464      0.519      0.311
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/150      5.56G      1.372      1.802   0.009015          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.9it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 25.5it/s 0.1s
#                    all         47        143      0.719       0.47      0.519       0.32
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/150      5.56G      1.429      1.825   0.009696          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.8it/s 4.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 25.3it/s 0.1s
#                    all         47        143       0.72      0.494       0.54      0.299
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/150      5.56G      1.429      1.836    0.01026          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.9it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 28.4it/s 0.1s
#                    all         47        143      0.724      0.441      0.526      0.291
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/150      5.56G      1.445      1.803     0.0093          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.8it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 24.9it/s 0.1s
#                    all         47        143      0.603       0.51      0.527      0.286
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/150      5.56G      1.398      1.727   0.009513          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.8it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 25.0it/s 0.1s
#                    all         47        143      0.798       0.37      0.537      0.312
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/150      5.56G      1.386      1.798   0.009592          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.8it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 25.5it/s 0.1s
#                    all         47        143      0.566      0.575      0.533      0.308
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/150      5.56G       1.41      1.756   0.009181          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.8it/s 4.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 25.7it/s 0.1s
#                    all         47        143      0.523      0.478      0.522      0.305
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/150      5.56G      1.355      1.597   0.009209          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.9it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 28.9it/s 0.1s
#                    all         47        143      0.685      0.457       0.54      0.314
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/150      5.56G       1.37      1.649   0.009047          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.9it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 24.5it/s 0.1s
#                    all         47        143      0.573       0.48      0.523      0.316
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/150      5.56G      1.441      1.671   0.009766          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.7it/s 4.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 26.2it/s 0.1s
#                    all         47        143      0.512      0.483      0.548      0.275
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/150      5.56G      1.387      1.607   0.009266          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.8it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 26.2it/s 0.1s
#                    all         47        143      0.552      0.601      0.589      0.341
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/150      5.56G       1.42      1.644   0.009507          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.8it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 25.2it/s 0.1s
#                    all         47        143      0.563      0.547      0.534      0.281
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/150      5.56G      1.417      1.536   0.009748          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.8it/s 4.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 25.0it/s 0.1s
#                    all         47        143      0.508      0.531      0.537       0.33
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/150      5.56G      1.389       1.58   0.009845          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.8it/s 4.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 26.1it/s 0.1s
#                    all         47        143      0.482      0.574      0.541      0.327
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/150      5.56G      1.349      1.521   0.009192          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.8it/s 4.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 25.2it/s 0.1s
#                    all         47        143      0.519      0.594      0.586      0.305
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/150      5.56G      1.395        1.5   0.009529          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.8it/s 4.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 25.8it/s 0.1s
#                    all         47        143      0.608      0.495      0.526       0.29
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/150      5.56G      1.387      1.441   0.009258          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.8it/s 4.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 27.9it/s 0.1s
#                    all         47        143      0.581      0.542      0.566      0.298
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/150      5.56G      1.372      1.473   0.008947          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.7it/s 4.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 25.6it/s 0.1s
#                    all         47        143      0.569      0.575      0.587      0.312
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/150      5.56G       1.37      1.418   0.009187          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.8it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 24.0it/s 0.1s
#                    all         47        143       0.53      0.545      0.548      0.324
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/150      5.56G      1.381       1.45   0.009057          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.9it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 26.0it/s 0.1s
#                    all         47        143      0.467      0.712      0.586      0.275
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/150      5.56G      1.361      1.394   0.008779          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.8it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 26.0it/s 0.1s
#                    all         47        143      0.546      0.623      0.613       0.33
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/150      5.56G      1.352      1.419   0.008925          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.9it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 25.3it/s 0.1s
#                    all         47        143      0.536      0.546      0.578      0.342
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/150      5.56G      1.348      1.298   0.009067          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.8it/s 4.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 24.7it/s 0.1s
#                    all         47        143      0.523      0.605      0.592      0.329
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/150      5.56G      1.346      1.356   0.009054          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.9it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 29.2it/s 0.1s
#                    all         47        143      0.477      0.617       0.59      0.315
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/150      5.56G      1.383       1.41   0.008809          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.8it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 26.0it/s 0.1s
#                    all         47        143      0.504      0.522      0.572      0.321
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/150      5.56G      1.377      1.356   0.008767          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.9it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 25.2it/s 0.1s
#                    all         47        143      0.462      0.604      0.574      0.315
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/150      5.56G      1.356      1.358   0.009127          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.9it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 25.3it/s 0.1s
#                    all         47        143      0.596      0.529       0.57      0.309
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/150      5.56G       1.34      1.275   0.009383          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.7it/s 4.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 27.1it/s 0.1s
#                    all         47        143      0.472      0.555      0.548      0.323
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/150      5.56G      1.374      1.356   0.009373          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.8it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 25.7it/s 0.1s
#                    all         47        143      0.433      0.546      0.544      0.311
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/150      5.56G      1.354      1.273   0.008606          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.9it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 25.3it/s 0.1s
#                    all         47        143      0.437      0.593      0.525      0.303
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/150      5.56G      1.364      1.249   0.009384          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.8it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 26.5it/s 0.1s
#                    all         47        143      0.512      0.564       0.56      0.343
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/150      5.56G      1.381      1.313   0.009219          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.8it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 25.3it/s 0.1s
#                    all         47        143      0.604        0.6       0.61      0.339
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/150      5.56G      1.321      1.267   0.008863          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.8it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 24.9it/s 0.1s
#                    all         47        143      0.486      0.555      0.568      0.339
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/150      5.56G      1.318       1.19    0.00878          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.7it/s 4.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 25.8it/s 0.1s
#                    all         47        143      0.666      0.589      0.637       0.35
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/150      5.56G      1.327      1.203   0.008775          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.8it/s 4.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 25.1it/s 0.1s
#                    all         47        143      0.629      0.587      0.619      0.396
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/150      5.56G      1.298      1.209   0.008724          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.8it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 27.0it/s 0.1s
#                    all         47        143      0.657      0.524      0.534      0.336
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/150      5.56G      1.281      1.172   0.008183          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.8it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 26.1it/s 0.1s
#                    all         47        143      0.558      0.575      0.593       0.35
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/150      5.56G      1.314      1.228   0.008703          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.8it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 24.7it/s 0.1s
#                    all         47        143      0.494       0.67      0.599      0.323
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/150      5.56G      1.309      1.162   0.008473          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.8it/s 4.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 25.9it/s 0.1s
#                    all         47        143       0.57      0.679      0.617       0.33
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/150      5.56G      1.322      1.209    0.00872          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.8it/s 4.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 24.0it/s 0.1s
#                    all         47        143      0.658      0.493      0.586      0.323
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/150      5.56G      1.301      1.146   0.008275          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.8it/s 4.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 25.7it/s 0.1s
#                    all         47        143      0.523      0.613      0.601      0.319
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/150      5.56G      1.323      1.136   0.008954          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.8it/s 4.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 25.3it/s 0.1s
#                    all         47        143      0.742      0.513      0.634      0.336
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/150      5.56G      1.321      1.163   0.008758          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.9it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 28.8it/s 0.1s
#                    all         47        143      0.633      0.551        0.6      0.337
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/150      5.56G      1.282      1.075   0.008485          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.8it/s 4.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 26.2it/s 0.1s
#                    all         47        143      0.611      0.635      0.626      0.373
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/150      5.56G      1.325      1.194   0.008562          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.7it/s 4.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 25.7it/s 0.1s
#                    all         47        143      0.611      0.615      0.611       0.35
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/150      5.56G      1.309      1.147   0.008988          2       1280: 100% ━━━━━━━━━━━━ 48/48 11.0it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 27.2it/s 0.1s
#                    all         47        143      0.724      0.524      0.634      0.354
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/150      5.56G      1.309      1.096   0.008503          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.8it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 26.9it/s 0.1s
#                    all         47        143      0.511       0.62      0.613      0.366
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/150      5.56G      1.304      1.102   0.009517          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.7it/s 4.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 25.7it/s 0.1s
#                    all         47        143      0.655      0.562      0.601      0.351
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/150      5.56G      1.251      1.084    0.00823          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.9it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 26.5it/s 0.1s
#                    all         47        143      0.709      0.583      0.609      0.354
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/150      5.56G      1.291      1.074   0.008338          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.7it/s 4.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 25.3it/s 0.1s
#                    all         47        143      0.639      0.559      0.633      0.349
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/150      5.56G      1.253      1.063   0.008678          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.7it/s 4.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 26.0it/s 0.1s
#                    all         47        143      0.616      0.571      0.579      0.323
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/150      5.56G      1.238      1.021    0.00814          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.9it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 25.6it/s 0.1s
#                    all         47        143      0.676      0.586      0.636      0.347
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/150      5.56G      1.301      1.008   0.008374          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.9it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 26.5it/s 0.1s
#                    all         47        143      0.566      0.641      0.637       0.37
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/150      5.56G      1.287      1.018   0.008347          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.9it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 25.1it/s 0.1s
#                    all         47        143       0.45      0.616      0.587      0.354
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/150      5.56G      1.226     0.9709   0.007896          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.8it/s 4.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 25.2it/s 0.1s
#                    all         47        143      0.453      0.673      0.521      0.322
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/150      5.56G      1.263     0.9855   0.007986          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.8it/s 4.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 26.6it/s 0.1s
#                    all         47        143      0.512      0.558      0.557      0.331
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/150      5.56G      1.241     0.9488   0.007999          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.9it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 25.6it/s 0.1s
#                    all         47        143      0.508      0.608      0.558      0.341
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/150      5.56G      1.231     0.9342   0.007884          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.9it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 26.1it/s 0.1s
#                    all         47        143      0.609      0.573      0.597       0.35
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/150      5.56G      1.245     0.9523   0.008101          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.9it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 26.1it/s 0.1s
#                    all         47        143      0.589       0.59      0.622      0.363
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/150      5.56G      1.248     0.9593   0.007962          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.8it/s 4.5s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 26.8it/s 0.1s
#                    all         47        143      0.532      0.607      0.613      0.348
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/150      5.56G      1.196     0.9708   0.007959          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.9it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 25.9it/s 0.1s
#                    all         47        143      0.549      0.567      0.606      0.344
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/150      5.56G      1.264     0.9613   0.007848          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.9it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 27.6it/s 0.1s
#                    all         47        143       0.53      0.609      0.591      0.354
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/150      5.56G      1.237     0.9661   0.007908          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.9it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 25.4it/s 0.1s
#                    all         47        143      0.523      0.575       0.55      0.324
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/150      5.56G      1.255     0.9562   0.008155          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.8it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 26.2it/s 0.1s
#                    all         47        143      0.539      0.614      0.583      0.339
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/150      5.56G       1.25     0.9254   0.008229          2       1280: 100% ━━━━━━━━━━━━ 48/48 10.9it/s 4.4s0.2s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 25.1it/s 0.1s
#                    all         47        143      0.538      0.575      0.578      0.345
# EarlyStopping: Training stopped early as no improvement observed in last 30 epochs. Best results observed at epoch 62, best model saved as best.pt.
# To update EarlyStopping(patience=30) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
#
# 92 epochs completed in 0.124 hours.
# Optimizer stripped from /home/pritamthapa/projects/cervical_cancer/ml-models/models/organism_det/checkpoints/yolo26n/weights/last.pt, 5.5MB
# Optimizer stripped from /home/pritamthapa/projects/cervical_cancer/ml-models/models/organism_det/checkpoints/yolo26n/weights/best.pt, 5.5MB
#
# Validating /home/pritamthapa/projects/cervical_cancer/ml-models/models/organism_det/checkpoints/yolo26n/weights/best.pt...
# Ultralytics 8.4.60 🚀 Python-3.10.12 torch-2.12.0+cu130 CUDA:0 (NVIDIA GeForce RTX 4090, 22554MiB)
# YOLO26n summary (fused): 122 layers, 2,375,616 parameters, 0 gradients, 5.2 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 23.4it/s 0.1s
#                    all         47        143      0.636      0.583      0.622      0.397
#  Trichomonas vaginalis         10         34       0.55      0.574      0.617      0.354
# Bacterial vaginosis flora shift         22         84      0.661      0.726      0.714      0.508
#           Candida spp.          8         19      0.333      0.211      0.202     0.0846
#       Actinomyces spp.          2          6          1       0.82      0.955       0.64
# Speed: 0.2ms preprocess, 0.8ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /home/pritamthapa/projects/cervical_cancer/ml-models/models/organism_det/checkpoints/yolo26n
# ultralytics.utils.metrics.DetMetrics object with attributes:
#
# ap_class_index: array([0, 1, 2, 3])
# box: ultralytics.utils.metrics.Metric object
# confusion_matrix: <ultralytics.utils.metrics.ConfusionMatrix object at 0x7f2145d52a40>
# curves: ['Precision-Recall(B)', 'F1-Confidence(B)', 'Precision-Confidence(B)', 'Recall-Confidence(B)']
# curves_results: [[array([          0,    0.001001,    0.002002,    0.003003,    0.004004,    0.005005,    0.006006,    0.007007,    0.008008,    0.009009,     0.01001,    0.011011,    0.012012,    0.013013,    0.014014,    0.015015,    0.016016,    0.017017,    0.018018,    0.019019,     0.02002,    0.021021,    0.022022,    0.023023,
#           0.024024,    0.025025,    0.026026,    0.027027,    0.028028,    0.029029,     0.03003,    0.031031,    0.032032,    0.033033,    0.034034,    0.035035,    0.036036,    0.037037,    0.038038,    0.039039,     0.04004,    0.041041,    0.042042,    0.043043,    0.044044,    0.045045,    0.046046,    0.047047,
#           0.048048,    0.049049,     0.05005,    0.051051,    0.052052,    0.053053,    0.054054,    0.055055,    0.056056,    0.057057,    0.058058,    0.059059,     0.06006,    0.061061,    0.062062,    0.063063,    0.064064,    0.065065,    0.066066,    0.067067,    0.068068,    0.069069,     0.07007,    0.071071,
# ...
#            0.93694,     0.93794,     0.93894,     0.93994,     0.94094,     0.94194,     0.94294,     0.94394,     0.94494,     0.94595,     0.94695,     0.94795,     0.94895,     0.94995,     0.95095,     0.95195,     0.95295,     0.95395,     0.95495,     0.95596,     0.95696,     0.95796,     0.95896,     0.95996,
#            0.96096,     0.96196,     0.96296,     0.96396,     0.96496,     0.96597,     0.96697,     0.96797,     0.96897,     0.96997,     0.97097,     0.97197,     0.97297,     0.97397,     0.97497,     0.97598,     0.97698,     0.97798,     0.97898,     0.97998,     0.98098,     0.98198,     0.98298,     0.98398,
#            0.98498,     0.98599,     0.98699,     0.98799,     0.98899,     0.98999,     0.99099,     0.99199,     0.99299,     0.99399,     0.99499,       0.996,       0.997,       0.998,       0.999,           1]), array([[    0.06044,    0.060568,    0.081003, ...,           1,           1,           1],
#        [   0.098381,      0.0984,     0.14884, ...,           1,           1,           1],
#        [   0.010554,    0.010555,    0.012539, ...,           1,           1,           1],
#        [   0.096774,    0.096774,     0.12245, ...,           1,           1,           1]], shape=(4, 1000)), 'Confidence', 'Precision'], [array([          0,    0.001001,    0.002002,    0.003003,    0.004004,    0.005005,    0.006006,    0.007007,    0.008008,    0.009009,     0.01001,    0.011011,    0.012012,    0.013013,    0.014014,    0.015015,    0.016016,    0.017017,    0.018018,    0.019019,     0.02002,    0.021021,    0.022022,    0.023023,
#           0.024024,    0.025025,    0.026026,    0.027027,    0.028028,    0.029029,     0.03003,    0.031031,    0.032032,    0.033033,    0.034034,    0.035035,    0.036036,    0.037037,    0.038038,    0.039039,     0.04004,    0.041041,    0.042042,    0.043043,    0.044044,    0.045045,    0.046046,    0.047047,
#           0.048048,    0.049049,     0.05005,    0.051051,    0.052052,    0.053053,    0.054054,    0.055055,    0.056056,    0.057057,    0.058058,    0.059059,     0.06006,    0.061061,    0.062062,    0.063063,    0.064064,    0.065065,    0.066066,    0.067067,    0.068068,    0.069069,     0.07007,    0.071071,
#           0.072072,    0.073073,    0.074074,    0.075075,    0.076076,    0.077077,    0.078078,    0.079079,     0.08008,    0.081081,    0.082082,    0.083083,    0.084084,    0.085085,    0.086086,    0.087087,    0.088088,    0.089089,     0.09009,    0.091091,    0.092092,    0.093093,    0.094094,    0.095095,
#           0.096096,    0.097097,    0.098098,    0.099099,      0.1001,      0.1011,      0.1021,      0.1031,      0.1041,     0.10511,     0.10611,     0.10711,     0.10811,     0.10911,     0.11011,     0.11111,     0.11211,     0.11311,     0.11411,     0.11512,     0.11612,     0.11712,     0.11812,     0.11912,
#            0.12012,     0.12112,     0.12212,     0.12312,     0.12412,     0.12513,     0.12613,     0.12713,     0.12813,     0.12913,     0.13013,     0.13113,     0.13213,     0.13313,     0.13413,     0.13514,     0.13614,     0.13714,     0.13814,     0.13914,     0.14014,     0.14114,     0.14214,     0.14314,
#            0.14414,     0.14515,     0.14615,     0.14715,     0.14815,     0.14915,     0.15015,     0.15115,     0.15215,     0.15315,     0.15415,     0.15516,     0.15616,     0.15716,     0.15816,     0.15916,     0.16016,     0.16116,     0.16216,     0.16316,     0.16416,     0.16517,     0.16617,     0.16717,
#            0.16817,     0.16917,     0.17017,     0.17117,     0.17217,     0.17317,     0.17417,     0.17518,     0.17618,     0.17718,     0.17818,     0.17918,     0.18018,     0.18118,     0.18218,     0.18318,     0.18418,     0.18519,     0.18619,     0.18719,     0.18819,     0.18919,     0.19019,     0.19119,
#            0.19219,     0.19319,     0.19419,      0.1952,      0.1962,      0.1972,      0.1982,      0.1992,      0.2002,      0.2012,      0.2022,      0.2032,      0.2042,     0.20521,     0.20621,     0.20721,     0.20821,     0.20921,     0.21021,     0.21121,     0.21221,     0.21321,     0.21421,     0.21522,
#            0.21622,     0.21722,     0.21822,     0.21922,     0.22022,     0.22122,     0.22222,     0.22322,     0.22422,     0.22523,     0.22623,     0.22723,     0.22823,     0.22923,     0.23023,     0.23123,     0.23223,     0.23323,     0.23423,     0.23524,     0.23624,     0.23724,     0.23824,     0.23924,
#            0.24024,     0.24124,     0.24224,     0.24324,     0.24424,     0.24525,     0.24625,     0.24725,     0.24825,     0.24925,     0.25025,     0.25125,     0.25225,     0.25325,     0.25425,     0.25526,     0.25626,     0.25726,     0.25826,     0.25926,     0.26026,     0.26126,     0.26226,     0.26326,
#            0.26426,     0.26527,     0.26627,     0.26727,     0.26827,     0.26927,     0.27027,     0.27127,     0.27227,     0.27327,     0.27427,     0.27528,     0.27628,     0.27728,     0.27828,     0.27928,     0.28028,     0.28128,     0.28228,     0.28328,     0.28428,     0.28529,     0.28629,     0.28729,
#            0.28829,     0.28929,     0.29029,     0.29129,     0.29229,     0.29329,     0.29429,      0.2953,      0.2963,      0.2973,      0.2983,      0.2993,      0.3003,      0.3013,      0.3023,      0.3033,      0.3043,     0.30531,     0.30631,     0.30731,     0.30831,     0.30931,     0.31031,     0.31131,
#            0.31231,     0.31331,     0.31431,     0.31532,     0.31632,     0.31732,     0.31832,     0.31932,     0.32032,     0.32132,     0.32232,     0.32332,     0.32432,     0.32533,     0.32633,     0.32733,     0.32833,     0.32933,     0.33033,     0.33133,     0.33233,     0.33333,     0.33433,     0.33534,
#            0.33634,     0.33734,     0.33834,     0.33934,     0.34034,     0.34134,     0.34234,     0.34334,     0.34434,     0.34535,     0.34635,     0.34735,     0.34835,     0.34935,     0.35035,     0.35135,     0.35235,     0.35335,     0.35435,     0.35536,     0.35636,     0.35736,     0.35836,     0.35936,
#            0.36036,     0.36136,     0.36236,     0.36336,     0.36436,     0.36537,     0.36637,     0.36737,     0.36837,     0.36937,     0.37037,     0.37137,     0.37237,     0.37337,     0.37437,     0.37538,     0.37638,     0.37738,     0.37838,     0.37938,     0.38038,     0.38138,     0.38238,     0.38338,
#            0.38438,     0.38539,     0.38639,     0.38739,     0.38839,     0.38939,     0.39039,     0.39139,     0.39239,     0.39339,     0.39439,      0.3954,      0.3964,      0.3974,      0.3984,      0.3994,      0.4004,      0.4014,      0.4024,      0.4034,      0.4044,     0.40541,     0.40641,     0.40741,
#            0.40841,     0.40941,     0.41041,     0.41141,     0.41241,     0.41341,     0.41441,     0.41542,     0.41642,     0.41742,     0.41842,     0.41942,     0.42042,     0.42142,     0.42242,     0.42342,     0.42442,     0.42543,     0.42643,     0.42743,     0.42843,     0.42943,     0.43043,     0.43143,
#            0.43243,     0.43343,     0.43443,     0.43544,     0.43644,     0.43744,     0.43844,     0.43944,     0.44044,     0.44144,     0.44244,     0.44344,     0.44444,     0.44545,     0.44645,     0.44745,     0.44845,     0.44945,     0.45045,     0.45145,     0.45245,     0.45345,     0.45445,     0.45546,
#            0.45646,     0.45746,     0.45846,     0.45946,     0.46046,     0.46146,     0.46246,     0.46346,     0.46446,     0.46547,     0.46647,     0.46747,     0.46847,     0.46947,     0.47047,     0.47147,     0.47247,     0.47347,     0.47447,     0.47548,     0.47648,     0.47748,     0.47848,     0.47948,
#            0.48048,     0.48148,     0.48248,     0.48348,     0.48448,     0.48549,     0.48649,     0.48749,     0.48849,     0.48949,     0.49049,     0.49149,     0.49249,     0.49349,     0.49449,      0.4955,      0.4965,      0.4975,      0.4985,      0.4995,      0.5005,      0.5015,      0.5025,      0.5035,
#             0.5045,     0.50551,     0.50651,     0.50751,     0.50851,     0.50951,     0.51051,     0.51151,     0.51251,     0.51351,     0.51451,     0.51552,     0.51652,     0.51752,     0.51852,     0.51952,     0.52052,     0.52152,     0.52252,     0.52352,     0.52452,     0.52553,     0.52653,     0.52753,
#            0.52853,     0.52953,     0.53053,     0.53153,     0.53253,     0.53353,     0.53453,     0.53554,     0.53654,     0.53754,     0.53854,     0.53954,     0.54054,     0.54154,     0.54254,     0.54354,     0.54454,     0.54555,     0.54655,     0.54755,     0.54855,     0.54955,     0.55055,     0.55155,
#            0.55255,     0.55355,     0.55455,     0.55556,     0.55656,     0.55756,     0.55856,     0.55956,     0.56056,     0.56156,     0.56256,     0.56356,     0.56456,     0.56557,     0.56657,     0.56757,     0.56857,     0.56957,     0.57057,     0.57157,     0.57257,     0.57357,     0.57457,     0.57558,
#            0.57658,     0.57758,     0.57858,     0.57958,     0.58058,     0.58158,     0.58258,     0.58358,     0.58458,     0.58559,     0.58659,     0.58759,     0.58859,     0.58959,     0.59059,     0.59159,     0.59259,     0.59359,     0.59459,      0.5956,      0.5966,      0.5976,      0.5986,      0.5996,
#             0.6006,      0.6016,      0.6026,      0.6036,      0.6046,     0.60561,     0.60661,     0.60761,     0.60861,     0.60961,     0.61061,     0.61161,     0.61261,     0.61361,     0.61461,     0.61562,     0.61662,     0.61762,     0.61862,     0.61962,     0.62062,     0.62162,     0.62262,     0.62362,
#            0.62462,     0.62563,     0.62663,     0.62763,     0.62863,     0.62963,     0.63063,     0.63163,     0.63263,     0.63363,     0.63463,     0.63564,     0.63664,     0.63764,     0.63864,     0.63964,     0.64064,     0.64164,     0.64264,     0.64364,     0.64464,     0.64565,     0.64665,     0.64765,
#            0.64865,     0.64965,     0.65065,     0.65165,     0.65265,     0.65365,     0.65465,     0.65566,     0.65666,     0.65766,     0.65866,     0.65966,     0.66066,     0.66166,     0.66266,     0.66366,     0.66466,     0.66567,     0.66667,     0.66767,     0.66867,     0.66967,     0.67067,     0.67167,
#            0.67267,     0.67367,     0.67467,     0.67568,     0.67668,     0.67768,     0.67868,     0.67968,     0.68068,     0.68168,     0.68268,     0.68368,     0.68468,     0.68569,     0.68669,     0.68769,     0.68869,     0.68969,     0.69069,     0.69169,     0.69269,     0.69369,     0.69469,      0.6957,
#             0.6967,      0.6977,      0.6987,      0.6997,      0.7007,      0.7017,      0.7027,      0.7037,      0.7047,     0.70571,     0.70671,     0.70771,     0.70871,     0.70971,     0.71071,     0.71171,     0.71271,     0.71371,     0.71471,     0.71572,     0.71672,     0.71772,     0.71872,     0.71972,
#            0.72072,     0.72172,     0.72272,     0.72372,     0.72472,     0.72573,     0.72673,     0.72773,     0.72873,     0.72973,     0.73073,     0.73173,     0.73273,     0.73373,     0.73473,     0.73574,     0.73674,     0.73774,     0.73874,     0.73974,     0.74074,     0.74174,     0.74274,     0.74374,
#            0.74474,     0.74575,     0.74675,     0.74775,     0.74875,     0.74975,     0.75075,     0.75175,     0.75275,     0.75375,     0.75475,     0.75576,     0.75676,     0.75776,     0.75876,     0.75976,     0.76076,     0.76176,     0.76276,     0.76376,     0.76476,     0.76577,     0.76677,     0.76777,
#            0.76877,     0.76977,     0.77077,     0.77177,     0.77277,     0.77377,     0.77477,     0.77578,     0.77678,     0.77778,     0.77878,     0.77978,     0.78078,     0.78178,     0.78278,     0.78378,     0.78478,     0.78579,     0.78679,     0.78779,     0.78879,     0.78979,     0.79079,     0.79179,
#            0.79279,     0.79379,     0.79479,      0.7958,      0.7968,      0.7978,      0.7988,      0.7998,      0.8008,      0.8018,      0.8028,      0.8038,      0.8048,     0.80581,     0.80681,     0.80781,     0.80881,     0.80981,     0.81081,     0.81181,     0.81281,     0.81381,     0.81481,     0.81582,
#            0.81682,     0.81782,     0.81882,     0.81982,     0.82082,     0.82182,     0.82282,     0.82382,     0.82482,     0.82583,     0.82683,     0.82783,     0.82883,     0.82983,     0.83083,     0.83183,     0.83283,     0.83383,     0.83483,     0.83584,     0.83684,     0.83784,     0.83884,     0.83984,
#            0.84084,     0.84184,     0.84284,     0.84384,     0.84484,     0.84585,     0.84685,     0.84785,     0.84885,     0.84985,     0.85085,     0.85185,     0.85285,     0.85385,     0.85485,     0.85586,     0.85686,     0.85786,     0.85886,     0.85986,     0.86086,     0.86186,     0.86286,     0.86386,
#            0.86486,     0.86587,     0.86687,     0.86787,     0.86887,     0.86987,     0.87087,     0.87187,     0.87287,     0.87387,     0.87487,     0.87588,     0.87688,     0.87788,     0.87888,     0.87988,     0.88088,     0.88188,     0.88288,     0.88388,     0.88488,     0.88589,     0.88689,     0.88789,
#            0.88889,     0.88989,     0.89089,     0.89189,     0.89289,     0.89389,     0.89489,      0.8959,      0.8969,      0.8979,      0.8989,      0.8999,      0.9009,      0.9019,      0.9029,      0.9039,      0.9049,     0.90591,     0.90691,     0.90791,     0.90891,     0.90991,     0.91091,     0.91191,
#            0.91291,     0.91391,     0.91491,     0.91592,     0.91692,     0.91792,     0.91892,     0.91992,     0.92092,     0.92192,     0.92292,     0.92392,     0.92492,     0.92593,     0.92693,     0.92793,     0.92893,     0.92993,     0.93093,     0.93193,     0.93293,     0.93393,     0.93493,     0.93594,
#            0.93694,     0.93794,     0.93894,     0.93994,     0.94094,     0.94194,     0.94294,     0.94394,     0.94494,     0.94595,     0.94695,     0.94795,     0.94895,     0.94995,     0.95095,     0.95195,     0.95295,     0.95395,     0.95495,     0.95596,     0.95696,     0.95796,     0.95896,     0.95996,
#            0.96096,     0.96196,     0.96296,     0.96396,     0.96496,     0.96597,     0.96697,     0.96797,     0.96897,     0.96997,     0.97097,     0.97197,     0.97297,     0.97397,     0.97497,     0.97598,     0.97698,     0.97798,     0.97898,     0.97998,     0.98098,     0.98198,     0.98298,     0.98398,
#            0.98498,     0.98599,     0.98699,     0.98799,     0.98899,     0.98999,     0.99099,     0.99199,     0.99299,     0.99399,     0.99499,       0.996,       0.997,       0.998,       0.999,           1]), array([[    0.97059,     0.97059,     0.94118, ...,           0,           0,           0],
#        [    0.94048,     0.94048,     0.92857, ...,           0,           0,           0],
#        [    0.84211,     0.84211,     0.84211, ...,           0,           0,           0],
#        [          1,           1,           1, ...,           0,           0,           0]], shape=(4, 1000)), 'Confidence', 'Recall']]
# fitness: 0.39667569068801456
# keys: ['metrics/precision(B)', 'metrics/recall(B)', 'metrics/mAP50(B)', 'metrics/mAP50-95(B)']
# maps: array([    0.35368,      0.5081,    0.084603,     0.64032])
# names: {0: 'Trichomonas vaginalis', 1: 'Bacterial vaginosis flora shift', 2: 'Candida spp.', 3: 'Actinomyces spp.'}
# nt_per_class: array([34, 84, 19,  6])
# nt_per_image: array([10, 22,  8,  2])
# results_dict: {'metrics/precision(B)': 0.6357983423425608, 'metrics/recall(B)': 0.582817195521688, 'metrics/mAP50(B)': 0.6217508327829466, 'metrics/mAP50-95(B)': 0.39667569068801456, 'fitness': 0.39667569068801456}
# save_dir: PosixPath('/home/pritamthapa/projects/cervical_cancer/ml-models/models/organism_det/checkpoints/yolo26n')
# speed: {'preprocess': 0.15455995744705045, 'inference': 0.7607085744676295, 'loss': 0.0003120851052950998, 'postprocess': 0.04979876595651613}
# stats: {'tp': [], 'conf': [], 'pred_cls': [], 'target_cls': [], 'target_img': []}

# %% [markdown]
# ### Copy weights and training plots to results directories

# %%
import shutil

RUN_DIR = CHECKPOINT_DIR.parent / MODEL_VARIANT

for weight in ['best.pt', 'last.pt']:
    src = RUN_DIR / 'weights' / weight
    if src.exists():
        shutil.copy(src, CHECKPOINT_DIR / weight)

for fname in [
    'confusion_matrix.png', 'confusion_matrix_normalized.png',
    'PR_curve.png', 'F1_curve.png', 'results.png', 'labels.jpg',
]:
    src = RUN_DIR / fname
    if src.exists():
        shutil.copy(src, PLOTS_DIR / fname)

print(f'Weights → {CHECKPOINT_DIR}')
print(f'Plots   → {PLOTS_DIR}')
# Out:
# Weights → /home/pritamthapa/projects/cervical_cancer/ml-models/models/organism_det/checkpoints/yolo26n
# Plots   → /home/pritamthapa/projects/cervical_cancer/ml-models/models/organism_det/results/plots/yolo26n

# %% [markdown]
# ### Evaluate on val and test sets

# %%
import pandas as pd
from ultralytics import YOLO as _YOLO

CLASS_NAMES = [
    'Trichomonas vaginalis',
    'Bacterial vaginosis flora shift',
    'Candida spp.',
    'Actinomyces spp.',
]

best_model = _YOLO(str(CHECKPOINT_DIR / 'best.pt'))

rows = []
for split in ['val', 'test']:
    r = best_model.val(data=str(DATASET_YAML), split=split, imgsz=IMGSZ, verbose=False)
    row = {
        'model':     MODEL_VARIANT,
        'split':     split,
        'mAP50':     round(float(r.box.map50), 4),
        'mAP50_95':  round(float(r.box.map),   4),
        'precision': round(float(r.box.mp),     4),
        'recall':    round(float(r.box.mr),     4),
    }
    for i, name in enumerate(CLASS_NAMES):
        key = f'AP50_{name.replace(" ", "_")}'
        row[key] = round(float(r.box.ap50[i]), 4) if i < len(r.box.ap50) else None
    rows.append(row)

metrics_df = pd.DataFrame(rows)
out_path   = METRICS_DIR / f'{MODEL_VARIANT}_metrics.csv'
metrics_df.to_csv(out_path, index=False)
print(f'Saved → {out_path}\n')
print(metrics_df.to_string(index=False))
# Out:
# Ultralytics 8.4.60 🚀 Python-3.10.12 torch-2.12.0+cu130 CUDA:0 (NVIDIA GeForce RTX 4090, 22554MiB)
# YOLO26n summary (fused): 122 layers, 2,375,616 parameters, 0 gradients, 5.2 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 5826.9±947.2 MB/s, size: 147.0 KB)
# val: Scanning /home/pritamthapa/projects/cervical_cancer/ml-models/data/organisms_data/val/labels.cache... 47 images, 5 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 47/47 14.1Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 3.1it/s 1.0s0.7s
#                    all         47        143      0.625       0.59      0.618      0.389
# Speed: 4.6ms preprocess, 6.8ms inference, 0.0ms loss, 0.4ms postprocess per image
# Results saved to /home/pritamthapa/projects/cervical_cancer/ml-models/runs/detect/val
# Ultralytics 8.4.60 🚀 Python-3.10.12 torch-2.12.0+cu130 CUDA:0 (NVIDIA GeForce RTX 4090, 22554MiB)
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 351.6±59.5 MB/s, size: 138.0 KB)
# val: Scanning /home/pritamthapa/projects/cervical_cancer/ml-models/data/organisms_data/test/labels... 48 images, 1 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 48/48 4.7Kit/s 0.0s
# val: New cache created: /home/pritamthapa/projects/cervical_cancer/ml-models/data/organisms_data/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 3/3 3.2it/s 0.9s0.6s
#                    all         48        155      0.496       0.57      0.519      0.288
# Speed: 5.4ms preprocess, 3.0ms inference, 0.0ms loss, 0.1ms postprocess per image
# Results saved to /home/pritamthapa/projects/cervical_cancer/ml-models/runs/detect/val-2
# Saved → /home/pritamthapa/projects/cervical_cancer/ml-models/models/organism_det/results/metrics/yolo26n_metrics.csv
#
#   model split  mAP50  mAP50_95  precision  recall  AP50_Trichomonas_vaginalis  AP50_Bacterial_vaginosis_flora_shift  AP50_Candida_spp.  AP50_Actinomyces_spp.
# yolo26n   val 0.6181    0.3885     0.6252  0.5903                      0.6090                                0.7138             0.1948                 0.9550
# yolo26n  test 0.5192    0.2884     0.4963  0.5700                      0.4672                                0.6771             0.3209                 0.6117

# %% [markdown]
# ### Sample predictions on validation images

# %%
import random
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image

CLASS_COLORS = ['#e74c3c', '#2ecc71', '#3498db', '#f39c12']
val_images   = sorted((ROOT / 'data/organisms_data/val/images').glob('*.jpg'))
samples      = random.sample(val_images, min(8, len(val_images)))

fig, axes = plt.subplots(2, 4, figsize=(32, 14))
for ax, img_path in zip(axes.flat, samples):
    img   = Image.open(img_path)
    preds = best_model.predict(str(img_path), imgsz=IMGSZ, verbose=False)[0]
    ax.imshow(img)
    for box in preds.boxes:
        cls  = int(box.cls)
        conf = float(box.conf)
        x1, y1, x2, y2 = box.xyxy[0].tolist()
        rect = patches.Rectangle(
            (x1, y1), x2 - x1, y2 - y1,
            linewidth=2, edgecolor=CLASS_COLORS[cls], facecolor='none'
        )
        ax.add_patch(rect)
        label = f'{CLASS_NAMES[cls][:14]} {conf:.2f}'
        ax.text(x1, y1 - 4, label, color=CLASS_COLORS[cls], fontsize=6, fontweight='bold')
    ax.axis('off')
    ax.set_title(img_path.stem, fontsize=8)

fig.suptitle(f'{MODEL_VARIANT.upper()} — Validation Sample Predictions', fontsize=14)
plt.tight_layout()
out_path = PLOTS_DIR / 'sample_predictions.png'
plt.savefig(out_path, dpi=150, bbox_inches='tight')
plt.show()
print(f'Saved → {out_path}')
# Out:
# Saved → /home/pritamthapa/projects/cervical_cancer/ml-models/models/organism_det/results/plots/yolo26n/sample_predictions.png

# %% [markdown]
# ### Results summary

# %%
val_row  = metrics_df[metrics_df.split == 'val'].iloc[0]
test_row = metrics_df[metrics_df.split == 'test'].iloc[0]

print(f'\n{"=" * 62}')
print(f'  {MODEL_VARIANT.upper()}  RESULTS')
print(f'{"=" * 62}')
print(f'  {"Metric":<24} {"Val":>8} {"Test":>8}')
print(f'  {"-" * 42}')
for metric, label in [("mAP50", "mAP@50"), ("mAP50_95", "mAP@50-95"),
                       ("precision", "Precision"), ("recall", "Recall")]:
    print(f'  {label:<24} {val_row[metric]:>8.4f} {test_row[metric]:>8.4f}')
print(f'\n  Per-class AP@50 (test):')
for name in CLASS_NAMES:
    key    = f'AP50_{name.replace(" ", "_")}'
    val    = test_row.get(key)
    suffix = '  <- critical' if 'Trichomonas' in name else ''
    v_str  = f'{val:.4f}' if val is not None else 'N/A'
    print(f'    {name:<42} {v_str}{suffix}')
print(f'{"=" * 62}')
# Out:
# ==============================================================
#   YOLO26N  RESULTS
# ==============================================================
#   Metric                        Val     Test
#   ------------------------------------------
#   mAP@50                     0.6181   0.5192
#   mAP@50-95                  0.3885   0.2884
#   Precision                  0.6252   0.4963
#   Recall                     0.5903   0.5700
#
#   Per-class AP@50 (test):
#     Trichomonas vaginalis                      0.4672  <- critical
#     Bacterial vaginosis flora shift            0.6771
#     Candida spp.                               0.3209
#     Actinomyces spp.                           0.6117
# ==============================================================
